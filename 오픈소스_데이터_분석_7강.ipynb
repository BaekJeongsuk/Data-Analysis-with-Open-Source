# %% [markdown]
# <a href="https://colab.research.google.com/github/BaekJeongsuk/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_7%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 7강 - 데이터 전처리 2

# %% [markdown]
# ### 7-1 데이터 결측치 찾기

# %%
import pandas as pd
import numpy as np

data = {'이름': ['김철수', '이영희', '박민수', '최지훈', '정소희'],
        '나이': [25, 30, np.nan, 22, 35],
        '도시': ['서울', None, '인천', '서울', '대전'],
        '점수': [90, 85, np.nan, 80, 92]}

df = pd.DataFrame(data)

## 결측치 여부 확인
df.isnull()
df.isna()

## 열별, 행별 결측치 개수 확인
df.isnull().sum()  #열별 (세로 방향)
df.isnull().sum(axis=1)  #행별 (가로 방향)

## 특정 열, 행 결측치 확인
df.[df.isnull(), any(axis=1)]
df.[df['나이'], isnull()]

## 결측치가 아닌 항목 확인
df.notnull()

## 결측치 비율
df.isnull(),sum(),sum() / df.shape[0] * df.shape[1] * 100

# %% [markdown]
# ### 7-2 데이터 시각화를 이용한 결측치 찾기

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache –fv
# !rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
import numpy as np
import pandas as pd

### 시각화 라이브러리 임포트

data = {'이름': ['김철수', '이영희', '박민수', '최지훈', '정소희'],
        '나이': [25, 30, np.nan, 22, 35],
        '도시': ['서울', None, '인천', '서울', '대전'],
        '점수': [90, 85, np.nan, 80, 92]}
df = pd.DataFrame(data)

### 결측치 히트맵
plt.figure(figsize=(8, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("결측치 히트맵")
plt.show()

### 결측치 매트릭스
msno.matrix(df)
plt.title("결측치 매트릭스")
plt.show()

# %% [markdown]
# ### 7-3 사분위 범위를 통한 이상치 찾기

# %%
import pandas as pd
import numpy as np

점수_데이터 = [72, 68, 75, 282, 64, 31, 78, 69, 88, 92, 22, 84, 61, -90, 130, 66]
학번_데이터 = list(range(1001, 1001 + len(점수_데이터)))

df = pd.DataFrame({
    '학번': 학번_데이터,
    '점수': 점수_데이터
})

### 사분위 범위 경계값 계산


### IQR 통계량 출력

# %% [markdown]
# ### 7-4 Z-점수를 통한 이상치 찾기

# %%
import pandas as pd
import numpy as np

점수_데이터 = [72, 68, 75, 282, 64, 31, 78, 69, 88, 92, 22, 84, 61, -90, 130, 66]
학번_데이터 = list(range(1001, 1001 + len(점수_데이터)))

df = pd.DataFrame({
    '학번': 학번_데이터,
    '점수': 점수_데이터
})

### Z-점수 계산

### 임계값 설정 및 이상치 여부 판단

### 이상치 데이터 출력

### 이상치 비율 출력

# %% [markdown]
# ### 7-5 평균값 및 선형보간법을 통한 결측치 처리

# %%
import pandas as pd
import numpy as np

file_path = "raw_large_shopping_customer.csv"
df = pd.read_csv(file_path)
print(df.isnull().sum())

df_cleaned = df.dropna(thresh=df.shape[1] - 1)

### 나이, 소득 평균값 대치 및 결과 출력


### 지출, 평균구매횟수 선형보간법 적용


df_cleaned.to_csv("cleaned_large_shopping_customer.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ### 7-6 DataFrame 값 변경

# %%
import pandas as pd

data = {'age': [25, 30, None, 22, 35],
        'city': ['Seoul', None, 'Incheon', 'Seoul', 'Daejeon'],
        'score': [90, 85, None, 80, 92]}
df = pd.DataFrame(data)

### replace를 이용한 Seoul -> 서울

### replace를 이용한 None -> 미정, Incheon -> 인천

### map을 이용한 값 변경
city_map = {'Seoul': '서울특별시', None: '미정', 'Incheon':'인천광역시', 'Daejeon':'대전광역시'}

### apply 함수를 이용한 값 변경

### apply 함수를 이용한 행단위 값 변경

### loc 인덱스를 이용한 값 변경

### where 함수를 이용한 값 변경

# %% [markdown]
# ### 7-7 날짜 데이터 타입 다루기

# %%
date_str = ['2025-07-01', '2025-08-01', '2025-09-01']
df_date = pd.DataFrame({'date_str':date_str})

### datetime 타입 변환

### 날짜 데이터 분리

### 날짜 데이터 포멧 변경

# %% [markdown]
# ## 7-8 실습 시나리오 - 데이터 정제

# %% [markdown]
# ### [재수행] 6-5 실습 시나리오 - Kaggle을 활용한 데이터 수집 및 측정

# %% [markdown]
# ### 데이터 분포 시각화

# %%
plt.figure(figsize=(10, 6))
sns.histplot(train['sales'], bins=50)
plt.title("판매량 분포")
plt.xlabel("판매량")
plt.ylabel("빈도")
plt.xlim(0, 5000)
plt.show()

store_sales = train.groupby('store_nbr')['sales'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x='store_nbr', y='sales', data=store_sales)
plt.title("매장별 평균 판매량")
plt.xlabel("매장 번호")
plt.ylabel("평균 판매량")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 결측치 처리

# %%
## 판매, 매장, 거래, 원유, 휴일이벤트 데이터 결측치

# %%
import missingno as msno

msno.matrix(oil)
plt.title("원유 가격 데이터 결측치 분포")
plt.show()

oil['date'] = pd.to_datetime(oil['date'])
plt.figure(figsize=(12, 6))
plt.plot(oil['date'], oil['dcoilwtico'])
plt.title("시간에 따른 원유 가격 변화")
plt.xlabel("날짜")
plt.ylabel("원유 가격")
plt.grid(True)
plt.show()

# %%
oil_cleaned = oil.copy()

### 선형 보간법 적용한 원유 가격 데이터


plt.figure(figsize=(12, 6))
plt.plot(oil_cleaned['date'], oil_cleaned['dcoilwtico'], 'b-')
plt.title("원유 가격 보간 후 데이터")
plt.xlabel("날짜")
plt.ylabel("원유 가격")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 이상치 처리

# %%
### 제품 계열별 판매 데이터 IQR 계산


### 상한값 초과 판매량 이상치 분류


print(f"이상치 개수: {total_outliers:,}건")
print(f"전체 대비 비율: {total_ratio:.2%}")

plt.figure(figsize=(15,6))
sns.stripplot(x='family', y='sales', hue=train_enhanced['is_outlier'],
              data=train_enhanced, palette={False:'blue', True:'red'})
plt.xticks(rotation=90)
plt.yscale('log')
plt.title('계열별 판매량 분포 (파랑: 정상, 빨강: 이상)')
plt.show()

# %%
upper_bounds = family_bounds['upper_bound']

### 판매량이 상한값 초과 시, 판매량으로 상한값으로 대체
train_cleaned  = train.copy()


changed_count = (train['sales'] != train_cleaned ['sales']).sum()
print(f"대체된 데이터 수: {changed_count}건")

# %% [markdown]
# ### 날짜 데이터 처리

# %%
### 판매, 거래, 휴일 이벤트, 원율 데이터 내 date 컬럼 데이터 datetime 데이터 타입으로 변경



train_cleaned['year'] = train_cleaned['date'].dt.year
train_cleaned['month'] = train_cleaned['date'].dt.month
train_cleaned['day'] = train_cleaned['date'].dt.day
train_cleaned['dayofweek'] = train_cleaned['date'].dt.dayofweek
### 주말, 월초, 월말 여부 추철


print("날짜 특성 추출 결과:")
print(train_cleaned[['date', 'year', 'month', 'day', 'dayofweek', 'weekend', 'is_month_start', 'is_month_end']].head())

# %%
## 요일별 평균 판매량을 계산

## 요일 출력값 변경

plt.figure(figsize=(10, 6))
sns.barplot(x='day_name', y='sales', data=day_sales)
plt.title("요일별 평균 판매량")
plt.xlabel("요일")
plt.ylabel("평균 판매량")
plt.show()

# %% [markdown]
# ### 데이터 통합

# %%
## 판매, 거래 데이터 통합


## 매장 데이터 통합


## 원유 데이터 통합


print("최종 데이터셋 정보:")
print(f"행 개수: {train_final.shape[0]}, 열 개수: {train_final.shape[1]}")
print(train_final.columns.tolist())
print(train_final.head())

# %%
import requests

def get_year_months():
    year_months = []
    for year in range(2015, 2024+1):
        for month in range(1, 12+1):
            year_months.append(f'{year}{month:02d}')
    return year_months

api_key = '72557745436261653436656d5a764d'
responses = []

for year_month in get_year_months():
    year = year_month[:4]
    month = year_month[4:]

    url = f"http://openapi.seoul.go.kr:8088/{api_key}/json/energyUseDataSummaryInfo/1/100/{year}/{month}"

    try:
        response = requests.get(url)
        if response.status_code == 200:
           print(f"{year}-{month} api 호출 성공")
           data = response.json()
           responses.append(data)
        else:
           print(f"{year}-{month} api 호출 실패: {response.status_code}")
    except Exception as e:
        print(f"{year}-{month} api 호출 예외: {e}")
# Out:
# 2015-01 api 호출 성공
# 2015-02 api 호출 성공
# 2015-03 api 호출 성공
# 2015-04 api 호출 성공
# 2015-05 api 호출 성공
# 2015-06 api 호출 성공
# 2015-07 api 호출 성공
# 2015-08 api 호출 성공
# 2015-09 api 호출 성공
# 2015-10 api 호출 성공
# 2015-11 api 호출 성공
# 2015-12 api 호출 성공
# 2016-01 api 호출 성공
# 2016-02 api 호출 성공
# 2016-03 api 호출 성공
# 2016-04 api 호출 성공
# 2016-05 api 호출 성공
# 2016-06 api 호출 성공
# 2016-07 api 호출 성공
# 2016-08 api 호출 성공
# 2016-09 api 호출 성공
# 2016-10 api 호출 성공
# 2016-11 api 호출 성공
# 2016-12 api 호출 성공
# 2017-01 api 호출 성공
# 2017-02 api 호출 성공
# 2017-03 api 호출 성공
# 2017-04 api 호출 성공
# 2017-05 api 호출 성공
# 2017-06 api 호출 성공
# 2017-07 api 호출 성공
# 2017-08 api 호출 성공
# 2017-09 api 호출 성공
# 2017-10 api 호출 성공
# 2017-11 api 호출 성공
# 2017-12 api 호출 성공
# 2018-01 api 호출 성공
# 2018-02 api 호출 성공
# 2018-03 api 호출 성공
# 2018-04 api 호출 성공
# 2018-05 api 호출 성공
# 2018-06 api 호출 성공
# 2018-07 api 호출 성공
# 2018-08 api 호출 성공
# 2018-09 api 호출 성공
# 2018-10 api 호출 성공
# 2018-11 api 호출 성공
# 2018-12 api 호출 성공
# 2019-01 api 호출 성공
# 2019-02 api 호출 성공
# 2019-03 api 호출 성공
# 2019-04 api 호출 성공
# 2019-05 api 호출 성공
# 2019-06 api 호출 성공
# 2019-07 api 호출 성공
# 2019-08 api 호출 성공
# 2019-09 api 호출 성공
# 2019-10 api 호출 성공
# 2019-11 api 호출 성공
# 2019-12 api 호출 성공
# 2020-01 api 호출 성공
# 2020-02 api 호출 성공
# 2020-03 api 호출 성공
# 2020-04 api 호출 성공
# 2020-05 api 호출 성공
# 2020-06 api 호출 성공
# 2020-07 api 호출 성공
# 2020-08 api 호출 성공
# 2020-09 api 호출 성공
# 2020-10 api 호출 성공
# 2020-11 api 호출 성공
# 2020-12 api 호출 성공
# 2021-01 api 호출 성공
# 2021-02 api 호출 성공
# 2021-03 api 호출 성공
# 2021-04 api 호출 성공
# 2021-05 api 호출 성공
# 2021-06 api 호출 성공
# 2021-07 api 호출 성공
# 2021-08 api 호출 성공
# 2021-09 api 호출 성공
# 2021-10 api 호출 성공
# 2021-11 api 호출 성공
# 2021-12 api 호출 성공
# 2022-01 api 호출 성공
# 2022-02 api 호출 성공
# 2022-03 api 호출 성공
# 2022-04 api 호출 성공
# 2022-05 api 호출 성공
# 2022-06 api 호출 성공
# 2022-07 api 호출 성공
# 2022-08 api 호출 성공
# 2022-09 api 호출 성공
# 2022-10 api 호출 성공
# 2022-11 api 호출 성공
# 2022-12 api 호출 성공
# 2023-01 api 호출 성공
# 2023-02 api 호출 성공
# 2023-03 api 호출 성공
# 2023-04 api 호출 성공
# 2023-05 api 호출 성공
# 2023-06 api 호출 성공
# 2023-07 api 호출 성공
# 2023-08 api 호출 성공
# 2023-09 api 호출 성공
# 2023-10 api 호출 성공
# 2023-11 api 호출 성공
# 2023-12 api 호출 성공
# 2024-01 api 호출 성공
# 2024-02 api 호출 성공
# 2024-03 api 호출 성공
# 2024-04 api 호출 성공
# 2024-05 api 호출 성공
# 2024-06 api 호출 성공
# 2024-07 api 호출 성공
# 2024-08 api 호출 성공
# 2024-09 api 호출 성공
# 2024-10 api 호출 성공
# 2024-11 api 호출 성공
# 2024-12 api 호출 성공

# %%
response.json()
# Out:
# {'energyUseDataSummaryInfo': {'list_total_count': 7,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'YEAR': '2024',
#     'MON': '12',
#     'MM_TYPE': '공동주택관리소',
#     'CNT': '3716',
#     'EUS': '548480228',
#     'EUS1': '557799290',
#     'EUS2': '559693904',
#     'ECO2_1': '-10266369',
#     'ECO2_2': '-10266369',
#     'GUS': '8221238',
#     'GUS1': '9759209',
#     'GUS2': '9093999',
#     'GCO2_1': '-1114991.5',
#     'GCO2_2': '-2229983',
#     'WUS': '20262147.7',
#     'WUS1': '20228097.5',
#     'WUS2': '20488646.8',
#     'WCO2_1': '-96224.45',
#     'WCO2_2': '-288673.35',
#     'HUS': '0',
#     'HUS1': '0',
#     'HUS2': '0',
#     'HCO2_1': '0',
#     'HCO2_2': '0',
#     'REG_DATE': '2025-03-01 04:02:55.0'},
#    {'YEAR': '2024',
#     'MON': '12',
#     'MM_TYPE': '기업',
#     'CNT': '19451',
#     'EUS': '633735769',
#     'EUS1': '641412053',
#     'EUS2': '669494932',
#     'ECO2_1': '-21717723.5',
#     'ECO2_2': '-21717723.5',
#     'GUS': '30096486',
#     'GUS1': '45742965',
#     'GUS2': '34384677',
#     'GCO2_1': '-9960022.5',
#     'GCO2_2': '-19920045',
#     'WUS': '4448777.4',
#     'WUS1': '4406465.4',
#     'WUS2': '4396396.4',
#     'WCO2_1': '47346.5',
#     'WCO2_2': '142039.5',
#     'HUS': '0',
#     'HUS1': '0',
#     'HUS2': '0',
#     'HCO2_1': '0',
#     'HCO2_2': '0',
#     'REG_DATE': '2025-03-01 04:02:55.0'},
#    {'YEAR': '2024',
#     'MON': '12',
#     'MM_TYPE': '개인',
#     'CNT': '1250620',
#     'EUS': '134828126',
#     'EUS1': '138280636',
#     'EUS2': '138879530',
#     'ECO2_1': '-3751957',
#     'ECO2_2': '-3504709',
#     'GUS': '42103424',
#     'GUS1': '47763373',
#     'GUS2': '46794290',
#     'GCO2_1': '-5135298',
#     'GCO2_2': '-10270596',
#     'WUS': '7326853.6',
#     'WUS1': '7440605',
#     'WUS2': '7625718.9',
#     'WCO2_1': '-206308.35',
#     'WCO2_2': '-573725.128',
#     'HUS': '1513199.277',
#     'HUS1': '1598857.184',
#     'HUS2': '1781397.386',
#     'HCO2_1': '-176928.008',
#     'HCO2_2': '-376996.699240516',
#     'REG_DATE': '2025-03-01 04:02:55.0'},
#    {'YEAR': '2024',
#     'MON': '12',
#     'MM_TYPE': '공공기관',
#     'CNT': '2459',
#     'EUS': '152992881',
#     'EUS1': '161100765',
#     'EUS2': '162060905',
#     'ECO2_1': '-8587954',
#     'ECO2_2': '-8587954',
#     'GUS': '3814815',
#     'GUS1': '4485938',
#     'GUS2': '4347791',
#     'GCO2_1': '-601856',
#     'GCO2_2': '-1203712',
#     'WUS': '896842',
#     'WUS1': '854671.2',
#     'WUS2': '833317.4',
#     'WCO2_1': '52847.7',
#     'WCO2_2': '158543.1',
#     'HUS': '0',
#     'HUS1': '0',
#     'HUS2': '0',
#     'HCO2_1': '0',
#     'HCO2_2': '0',
#     'REG_DATE': '2025-03-01 04:02:55.0'},
#    {'YEAR': '2024',
#     'MON': '12',
#     'MM_TYPE': '학교',
#     'CNT': '6742',
#     'EUS': '164092999',
#     'EUS1': '170867152',
#     'EUS2': '169660376',
#     'ECO2_1': '-6170678',
#     'ECO2_2': '-6172770.32',
#     'GUS': '4362563',
#     'GUS1': '4794450',
#     'GUS2': '4840884',
#     'GCO2_1': '-452916.5',
#     'GCO2_2': '-905833',
#     'WUS': '1858841',
#     'WUS1': '1898794',
#     'WUS2': '1939698.4',
#     'WCO2_1': '-60405.2',
#     'WCO2_2': '-181607.796',
#     'HUS': '1062.62',
#     'HUS1': '902.03',
#     'HUS2': '1220.91',
#     'HCO2_1': '1.15',
#     'HCO2_2': '3.3315',
#     'REG_DATE': '2025-03-01 04:02:55.0'},
#    {'YEAR': '2024',
#     'MON': '12',
#     'MM_TYPE': '소상공인',
#     'CNT': '53031',
#     'EUS': '101773064',
#     'EUS1': '105830842',
#     'EUS2': '106996097',
#     'ECO2_1': '-4640405.5',
#     'ECO2_2': '-4640315.356',
#     'GUS': '2544825',
#     'GUS1': '2719970',
#     'GUS2': '2842004',
#     'GCO2_1': '-234683',
#     'GCO2_2': '-469366',
#     'WUS': '1560686.6',
#     'WUS1': '1540086.6',
#     'WUS2': '1542971',
#     'WCO2_1': '19157.8',
#     'WCO2_2': '57349.338',
#     'HUS': '360',
#     'HUS1': '395',
#     'HUS2': '470',
#     'HCO2_1': '-72.5',
#     'HCO2_2': '-288.695',
#     'REG_DATE': '2025-03-01 04:02:55.0'},
#    {'YEAR': '2024',
#     'MON': '12',
#     'MM_TYPE': '종교단체',
#     'CNT': '847',
#     'EUS': '7922631',
#     'EUS1': '8361049',
#     'EUS2': '8016890',
#     'ECO2_1': '-266338.5',
#     'ECO2_2': '-266338.5',
#     'GUS': '309429',
#     'GUS1': '378759',
#     'GUS2': '355715',
#     'GCO2_1': '-57056.5',
#     'GCO2_2': '-114113',
#     'WUS': '51695',
#     'WUS1': '48661',
#     'WUS2': '48241',
#     'WCO2_1': '3244',
#     'WCO2_2': '9732',
#     'HUS': '0',
#     'HUS1': '0',
#     'HUS2': '0',
#     'HCO2_1': '0',
#     'HCO2_2': '0',
#     'REG_DATE': '2025-03-01 04:02:55.0'}]}}

# %%
responses
# Out:
# [{'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '01',
#      'MM_TYPE': '개인',
#      'CNT': '767791',
#      'EUS': '193784708',
#      'EUS1': '194781915',
#      'EUS2': '204969429',
#      'ECO2_1': '-6090964',
#      'ECO2_2': '-2582568.736',
#      'GUS': '59133720',
#      'GUS1': '57163993',
#      'GUS2': '68297619',
#      'GCO2_1': '-3597086',
#      'GCO2_2': '-8057472.64',
#      'WUS': '12819757.886',
#      'WUS1': '12723680.426',
#      'WUS2': '12899476.73',
#      'WCO2_1': '8179.308',
#      'WCO2_2': '2715.530256',
#      'HUS': '22740838.937',
#      'HUS1': '23400055.303',
#      'HUS2': '27090493.875',
#      'HCO2_1': '-2504435.652',
#      'HCO2_2': '-33660084.213069',
#      'REG_DATE': '2015-06-04 17:03:55.0'},
#     {'YEAR': '2015',
#      'MON': '01',
#      'MM_TYPE': '학교',
#      'CNT': '1382',
#      'EUS': '134955565',
#      'EUS1': '128707423',
#      'EUS2': '145561511',
#      'ECO2_1': '-2178902',
#      'ECO2_2': '-923854.448',
#      'GUS': '9107197',
#      'GUS1': '8410968',
#      'GUS2': '10745416',
#      'GCO2_1': '-470995',
#      'GCO2_2': '-1055028.8',
#      'WUS': '2075819.2',
#      'WUS1': '2097433.8',
#      'WUS2': '2133200.8',
#      'WCO2_1': '-39498.1',
#      'WCO2_2': '-13113.3692',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 17:03:55.0'},
#     {'YEAR': '2015',
#      'MON': '01',
#      'MM_TYPE': '종교단체',
#      'CNT': '32',
#      'EUS': '372270',
#      'EUS1': '363376',
#      'EUS2': '411363',
#      'ECO2_1': '-15099.5',
#      'ECO2_2': '-6402.188',
#      'GUS': '53331',
#      'GUS1': '45727',
#      'GUS2': '63312',
#      'GCO2_1': '-1188.5',
#      'GCO2_2': '-2662.24',
#      'WUS': '5945',
#      'WUS1': '4548',
#      'WUS2': '4519',
#      'WCO2_1': '1411.5',
#      'WCO2_2': '468.618',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 17:03:55.0'},
#     {'YEAR': '2015',
#      'MON': '01',
#      'MM_TYPE': '소상공인',
#      'CNT': '2058',
#      'EUS': '10249618',
#      'EUS1': '9927610',
#      'EUS2': '11039593',
#      'ECO2_1': '-233983.5',
#      'ECO2_2': '-99209.004',
#      'GUS': '536119',
#      'GUS1': '523810',
#      'GUS2': '642921',
#      'GCO2_1': '-47246.5',
#      'GCO2_2': '-105832.16',
#      'WUS': '147273',
#      'WUS1': '146480.6',
#      'WUS2': '147325.6',
#      'WCO2_1': '369.9',
#      'WCO2_2': '122.8068',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 17:03:55.0'},
#     {'YEAR': '2015',
#      'MON': '01',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1747',
#      'EUS': '327102096',
#      'EUS1': '329852334',
#      'EUS2': '351694752',
#      'ECO2_1': '-13671447',
#      'ECO2_2': '-5796693.528',
#      'GUS': '22834274',
#      'GUS1': '21141017',
#      'GUS2': '25338506',
#      'GCO2_1': '-405487.5',
#      'GCO2_2': '-908292',
#      'WUS': '12844807.5',
#      'WUS1': '12763070',
#      'WUS2': '12979835.8',
#      'WCO2_1': '-26645.4',
#      'WCO2_2': '-8846.2728',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 17:03:55.0'},
#     {'YEAR': '2015',
#      'MON': '01',
#      'MM_TYPE': '기업',
#      'CNT': '16751',
#      'EUS': '583090528',
#      'EUS1': '586779350',
#      'EUS2': '632471031',
#      'ECO2_1': '-26534662.5',
#      'ECO2_2': '-11250696.9',
#      'GUS': '37835680',
#      'GUS1': '35765271',
#      'GUS2': '47713673',
#      'GCO2_1': '-3903792',
#      'GCO2_2': '-8744494.08',
#      'WUS': '6581017',
#      'WUS1': '6591203.4',
#      'WUS2': '6684708.2',
#      'WCO2_1': '-56938.8',
#      'WCO2_2': '-18903.6816',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 17:03:55.0'},
#     {'YEAR': '2015',
#      'MON': '01',
#      'MM_TYPE': '공공기관',
#      'CNT': '2981',
#      'EUS': '247059373',
#      'EUS1': '242471579',
#      'EUS2': '261884067',
#      'ECO2_1': '-5118450',
#      'ECO2_2': '-2170222.8',
#      'GUS': '11524542',
#      'GUS1': '10057837',
#      'GUS2': '13760048',
#      'GCO2_1': '-384400.5',
#      'GCO2_2': '-861057.12',
#      'WUS': '1522465.2',
#      'WUS1': '1495786.6',
#      'WUS2': '1522178.8',
#      'WCO2_1': '13482.5',
#      'WCO2_2': '4476.19',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 17:03:55.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '02',
#      'MM_TYPE': '개인',
#      'CNT': '774620',
#      'EUS': '189974230',
#      'EUS1': '193611430',
#      'EUS2': '200055533',
#      'ECO2_1': '-6859251.5',
#      'ECO2_2': '-2908322.636',
#      'GUS': '56487358',
#      'GUS1': '59353536',
#      'GUS2': '66191173',
#      'GCO2_1': '-6284996.5',
#      'GCO2_2': '-14078392.16',
#      'WUS': '12656888.218',
#      'WUS1': '12713146.172',
#      'WUS2': '12948410.081',
#      'WCO2_1': '-173889.9085',
#      'WCO2_2': '-57731.449622',
#      'HUS': '18793320.213',
#      'HUS1': '19032221.757',
#      'HUS2': '21414367.325',
#      'HCO2_1': '-1429974.328',
#      'HCO2_2': '-17311712.76832',
#      'REG_DATE': '2015-06-04 16:59:30.0'},
#     {'YEAR': '2015',
#      'MON': '02',
#      'MM_TYPE': '기업',
#      'CNT': '16966',
#      'EUS': '523325778',
#      'EUS1': '542435234',
#      'EUS2': '567181200',
#      'ECO2_1': '-31482439',
#      'ECO2_2': '-13348554.136',
#      'GUS': '32508993',
#      'GUS1': '35169022',
#      'GUS2': '44168086',
#      'GCO2_1': '-7159561',
#      'GCO2_2': '-16037416.64',
#      'WUS': '6859860.8',
#      'WUS1': '6853247.6',
#      'WUS2': '7071961.8',
#      'WCO2_1': '-102743.9',
#      'WCO2_2': '-34110.9748',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 16:59:30.0'},
#     {'YEAR': '2015',
#      'MON': '02',
#      'MM_TYPE': '소상공인',
#      'CNT': '2153',
#      'EUS': '9763412',
#      'EUS1': '9786829',
#      'EUS2': '10214569',
#      'ECO2_1': '-237287',
#      'ECO2_2': '-100609.688',
#      'GUS': '500186',
#      'GUS1': '506300',
#      'GUS2': '583970',
#      'GCO2_1': '-44949',
#      'GCO2_2': '-100685.76',
#      'WUS': '187015.2',
#      'WUS1': '183563.4',
#      'WUS2': '194518.373',
#      'WCO2_1': '-2025.6865',
#      'WCO2_2': '-672.527918',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 16:59:30.0'},
#     {'YEAR': '2015',
#      'MON': '02',
#      'MM_TYPE': '공공기관',
#      'CNT': '2981',
#      'EUS': '230038970',
#      'EUS1': '227707037',
#      'EUS2': '239494601',
#      'ECO2_1': '-3561849',
#      'ECO2_2': '-1510223.976',
#      'GUS': '10730599',
#      'GUS1': '10003033',
#      'GUS2': '13321495',
#      'GCO2_1': '-931665',
#      'GCO2_2': '-2086929.6',
#      'WUS': '1398431.4',
#      'WUS1': '1283504.4',
#      'WUS2': '1331699.8',
#      'WCO2_1': '90829.3',
#      'WCO2_2': '30155.3276',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 16:59:30.0'},
#     {'YEAR': '2015',
#      'MON': '02',
#      'MM_TYPE': '종교단체',
#      'CNT': '32',
#      'EUS': '336476',
#      'EUS1': '341646',
#      'EUS2': '366928',
#      'ECO2_1': '-17811',
#      'ECO2_2': '-7551.864',
#      'GUS': '46069',
#      'GUS1': '49077',
#      'GUS2': '58309',
#      'GCO2_1': '-7624',
#      'GCO2_2': '-17077.76',
#      'WUS': '2019',
#      'WUS1': '2093',
#      'WUS2': '2527',
#      'WCO2_1': '-291',
#      'WCO2_2': '-96.612',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 16:59:30.0'},
#     {'YEAR': '2015',
#      'MON': '02',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1752',
#      'EUS': '316848045',
#      'EUS1': '323802835',
#      'EUS2': '338173958',
#      'ECO2_1': '-14140351.5',
#      'ECO2_2': '-5995509.036',
#      'GUS': '21345908',
#      'GUS1': '21525278',
#      'GUS2': '24530949',
#      'GCO2_1': '-1682205.5',
#      'GCO2_2': '-3768140.32',
#      'WUS': '13278519.4',
#      'WUS1': '13222458.8',
#      'WUS2': '13488565.8',
#      'WCO2_1': '-76992.9',
#      'WCO2_2': '-25561.6428',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 16:59:30.0'},
#     {'YEAR': '2015',
#      'MON': '02',
#      'MM_TYPE': '학교',
#      'CNT': '1384',
#      'EUS': '121210475',
#      'EUS1': '119670051',
#      'EUS2': '132649784',
#      'ECO2_1': '-4949442.5',
#      'ECO2_2': '-2098563.62',
#      'GUS': '7388457',
#      'GUS1': '7410433',
#      'GUS2': '8615797',
#      'GCO2_1': '-624658',
#      'GCO2_2': '-1399233.92',
#      'WUS': '1632715',
#      'WUS1': '1656710.6',
#      'WUS2': '1824616.6',
#      'WCO2_1': '-107948.6',
#      'WCO2_2': '-35838.9352',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-04 16:59:30.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '03',
#      'MM_TYPE': '학교',
#      'CNT': '3903',
#      'EUS': '145577747',
#      'EUS1': '140333207',
#      'EUS2': '148915260',
#      'ECO2_1': '673170',
#      'ECO2_2': '285424.08',
#      'GUS': '7601585',
#      'GUS1': '7048562',
#      'GUS2': '8350061',
#      'GCO2_1': '-97726.5',
#      'GCO2_2': '-218907.36',
#      'WUS': '2570265.8',
#      'WUS1': '2622179.4',
#      'WUS2': '2793577',
#      'WCO2_1': '-137612.4',
#      'WCO2_2': '-45687.3168',
#      'HUS': '48',
#      'HUS1': '34',
#      'HUS2': '41',
#      'HCO2_1': '10.5',
#      'HCO2_2': '41.811',
#      'REG_DATE': '2015-06-12 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '03',
#      'MM_TYPE': '공공기관',
#      'CNT': '2048',
#      'EUS': '208343249',
#      'EUS1': '206515245',
#      'EUS2': '211942654',
#      'ECO2_1': '-13629158',
#      'ECO2_2': '-5778762.992',
#      'GUS': '8141963',
#      'GUS1': '7814746',
#      'GUS2': '9821117',
#      'GCO2_1': '-675968.5',
#      'GCO2_2': '-1514169.44',
#      'WUS': '1392249.2',
#      'WUS1': '1374222.8',
#      'WUS2': '1459810.8',
#      'WCO2_1': '-24767.6',
#      'WCO2_2': '-8222.8432',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-12 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '03',
#      'MM_TYPE': '기업',
#      'CNT': '5334',
#      'EUS': '454517085',
#      'EUS1': '463464106',
#      'EUS2': '477564250',
#      'ECO2_1': '-16954537',
#      'ECO2_2': '-7188723.688',
#      'GUS': '21689961',
#      'GUS1': '20767213',
#      'GUS2': '26298201',
#      'GCO2_1': '-1842746',
#      'GCO2_2': '-4127751.04',
#      'WUS': '3992245',
#      'WUS1': '3999579',
#      'WUS2': '4116372.4',
#      'WCO2_1': '-65730.7',
#      'WCO2_2': '-21822.5924',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-12 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '03',
#      'MM_TYPE': '소상공인',
#      'CNT': '12277',
#      'EUS': '46364443',
#      'EUS1': '46668562',
#      'EUS2': '48429447',
#      'ECO2_1': '-11152776',
#      'ECO2_2': '-4728777.024',
#      'GUS': '4535233',
#      'GUS1': '4422360',
#      'GUS2': '5707623',
#      'GCO2_1': '-529758.5',
#      'GCO2_2': '-1186659.04',
#      'WUS': '1381256.6',
#      'WUS1': '1405384.8',
#      'WUS2': '1488573.8',
#      'WCO2_1': '-65722.7',
#      'WCO2_2': '-21819.9364',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-12 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '03',
#      'MM_TYPE': '종교단체',
#      'CNT': '227',
#      'EUS': '2819027',
#      'EUS1': '2752465',
#      'EUS2': '3096521',
#      'ECO2_1': '-732131',
#      'ECO2_2': '-310423.544',
#      'GUS': '303568',
#      'GUS1': '298193',
#      'GUS2': '374956',
#      'GCO2_1': '-33006.5',
#      'GCO2_2': '-73934.56',
#      'WUS': '23135',
#      'WUS1': '26200',
#      'WUS2': '28432',
#      'WCO2_1': '-4181',
#      'WCO2_2': '-1388.092',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-12 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '03',
#      'MM_TYPE': '개인',
#      'CNT': '783726',
#      'EUS': '175215719',
#      'EUS1': '177160755',
#      'EUS2': '182354932',
#      'ECO2_1': '-5541536.5',
#      'ECO2_2': '-2349611.476',
#      'GUS': '49984873',
#      'GUS1': '47364229',
#      'GUS2': '55230322',
#      'GCO2_1': '-1312402.5',
#      'GCO2_2': '-2939781.6',
#      'WUS': '12655474.249',
#      'WUS1': '12649879.288',
#      'WUS2': '12668246.94',
#      'WCO2_1': '-3588.865',
#      'WCO2_2': '-1191.50318',
#      'HUS': '13826348.508',
#      'HUS1': '12628762.116',
#      'HUS2': '14509117.099',
#      'HCO2_1': '257408.9005',
#      'HCO2_2': '11088622.213667',
#      'REG_DATE': '2015-06-12 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '03',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1754',
#      'EUS': '283026044',
#      'EUS1': '285957754',
#      'EUS2': '297805572',
#      'ECO2_1': '-8966181.5',
#      'ECO2_2': '-3801660.956',
#      'GUS': '18030531',
#      'GUS1': '17254476',
#      'GUS2': '20167614',
#      'GCO2_1': '-680514',
#      'GCO2_2': '-1524351.36',
#      'WUS': '12630070.5',
#      'WUS1': '12656818.7',
#      'WUS2': '12838049.1',
#      'WCO2_1': '-117363.4',
#      'WCO2_2': '-38964.6488',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-06-12 04:00:01.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '04',
#      'MM_TYPE': '학교',
#      'CNT': '4021',
#      'EUS': '134199179',
#      'EUS1': '130280899',
#      'EUS2': '148944597',
#      'ECO2_1': '-5413569',
#      'ECO2_2': '-2295353.256',
#      'GUS': '5544226',
#      'GUS1': '4827947',
#      'GUS2': '6248901',
#      'GCO2_1': '5802',
#      'GCO2_2': '12996.48',
#      'WUS': '3003915.8',
#      'WUS1': '3070009.2',
#      'WUS2': '3150480',
#      'WCO2_1': '-106328.8',
#      'WCO2_2': '-35301.1616',
#      'HUS': '9',
#      'HUS1': '8',
#      'HUS2': '16',
#      'HCO2_1': '-3',
#      'HCO2_2': '-11.946',
#      'REG_DATE': '2015-07-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '04',
#      'MM_TYPE': '소상공인',
#      'CNT': '12488',
#      'EUS': '44335889',
#      'EUS1': '44591444',
#      'EUS2': '46398712',
#      'ECO2_1': '-1159189',
#      'ECO2_2': '-491496.136',
#      'GUS': '3324279',
#      'GUS1': '3161927',
#      'GUS2': '4301451',
#      'GCO2_1': '-407410',
#      'GCO2_2': '-912598.4',
#      'WUS': '1535366.6',
#      'WUS1': '1568041.4',
#      'WUS2': '1587003',
#      'WCO2_1': '-42155.6',
#      'WCO2_2': '-13995.6592',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-07-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '04',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1768',
#      'EUS': '291394437',
#      'EUS1': '294559733',
#      'EUS2': '309664586',
#      'ECO2_1': '-10717722.5',
#      'ECO2_2': '-4544314.34',
#      'GUS': '14161336',
#      'GUS1': '13462421',
#      'GUS2': '15980238',
#      'GCO2_1': '-559993.5',
#      'GCO2_2': '-1254385.44',
#      'WUS': '13376543.7',
#      'WUS1': '13333763.4',
#      'WUS2': '13350196.8',
#      'WCO2_1': '34563.6',
#      'WCO2_2': '11475.1152',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-07-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '04',
#      'MM_TYPE': '기업',
#      'CNT': '5609',
#      'EUS': '436129598',
#      'EUS1': '448413355',
#      'EUS2': '459364439',
#      'ECO2_1': '-17759299',
#      'ECO2_2': '-7529942.776',
#      'GUS': '15169055',
#      'GUS1': '14667324',
#      'GUS2': '17942039',
#      'GCO2_1': '-1135626.5',
#      'GCO2_2': '-2543803.36',
#      'WUS': '4051942.6',
#      'WUS1': '4092409.6',
#      'WUS2': '4125632',
#      'WCO2_1': '-57078.2',
#      'WCO2_2': '-18949.9624',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-07-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '04',
#      'MM_TYPE': '종교단체',
#      'CNT': '249',
#      'EUS': '2697190',
#      'EUS1': '3106519',
#      'EUS2': '3552647',
#      'ECO2_1': '-632393',
#      'ECO2_2': '-268134.632',
#      'GUS': '244845',
#      'GUS1': '204903',
#      'GUS2': '276957',
#      'GCO2_1': '3915',
#      'GCO2_2': '8769.6',
#      'WUS': '26436',
#      'WUS1': '28596',
#      'WUS2': '34681',
#      'WCO2_1': '-5202.5',
#      'WCO2_2': '-1727.23',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-07-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '04',
#      'MM_TYPE': '공공기관',
#      'CNT': '2176',
#      'EUS': '207780906',
#      'EUS1': '205375968',
#      'EUS2': '215246086',
#      'ECO2_1': '-2530121',
#      'ECO2_2': '-1072771.304',
#      'GUS': '6190060',
#      'GUS1': '5461107',
#      'GUS2': '7039668',
#      'GCO2_1': '-60327.5',
#      'GCO2_2': '-135133.6',
#      'WUS': '1253420.8',
#      'WUS1': '1200942.4',
#      'WUS2': '1186735.8',
#      'WCO2_1': '59581.7',
#      'WCO2_2': '19781.1244',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-07-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '04',
#      'MM_TYPE': '개인',
#      'CNT': '798971',
#      'EUS': '183891769',
#      'EUS1': '187268491',
#      'EUS2': '193988954',
#      'ECO2_1': '-6736953.5',
#      'ECO2_2': '-2856468.284',
#      'GUS': '37306841',
#      'GUS1': '34346299',
#      'GUS2': '43437313',
#      'GCO2_1': '-1584965',
#      'GCO2_2': '-3550321.6',
#      'WUS': '12954773.246',
#      'WUS1': '13016364.788',
#      'WUS2': '13153635.106',
#      'WCO2_1': '-130226.701',
#      'WCO2_2': '-43235.264732',
#      'HUS': '5836002.885',
#      'HUS1': '5534118.758',
#      'HUS2': '8275382.274',
#      'HCO2_1': '-1068747.631',
#      'HCO2_2': '-27674867.802062',
#      'REG_DATE': '2015-07-05 04:00:00.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '05',
#      'MM_TYPE': '개인',
#      'CNT': '810422',
#      'EUS': '177289769',
#      'EUS1': '181972266',
#      'EUS2': '188230004',
#      'ECO2_1': '-7811366',
#      'ECO2_2': '-3312019.184',
#      'GUS': '22060892',
#      'GUS1': '21196763',
#      'GUS2': '30633727',
#      'GCO2_1': '-3854353',
#      'GCO2_2': '-8633750.72',
#      'WUS': '13086734.214',
#      'WUS1': '13214349.918',
#      'WUS2': '13186433.49',
#      'WCO2_1': '-113657.49',
#      'WCO2_2': '-37734.28668',
#      'HUS': '1320895.801',
#      'HUS1': '1558697.648',
#      'HUS2': '1709192.194',
#      'HCO2_1': '-313049.12',
#      'HCO2_2': '-5190153.166471',
#      'REG_DATE': '2015-08-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '05',
#      'MM_TYPE': '종교단체',
#      'CNT': '260',
#      'EUS': '2733596',
#      'EUS1': '3276493',
#      'EUS2': '3366363',
#      'ECO2_1': '-587832',
#      'ECO2_2': '-249240.768',
#      'GUS': '119561',
#      'GUS1': '110085',
#      'GUS2': '177320',
#      'GCO2_1': '-24141.5',
#      'GCO2_2': '-54076.96',
#      'WUS': '23511',
#      'WUS1': '26717',
#      'WUS2': '30786',
#      'WCO2_1': '-5240.5',
#      'WCO2_2': '-1739.846',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-08-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '05',
#      'MM_TYPE': '소상공인',
#      'CNT': '12466',
#      'EUS': '45864251',
#      'EUS1': '46065582',
#      'EUS2': '47630147',
#      'ECO2_1': '-983613.5',
#      'ECO2_2': '-417052.124',
#      'GUS': '2199716',
#      'GUS1': '2210180',
#      'GUS2': '2950302',
#      'GCO2_1': '-380525',
#      'GCO2_2': '-852376',
#      'WUS': '1403580.2',
#      'WUS1': '1444450.4',
#      'WUS2': '1412015.92',
#      'WCO2_1': '-24652.96',
#      'WCO2_2': '-8184.78272',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-08-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '05',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1751',
#      'EUS': '275543444',
#      'EUS1': '281778782',
#      'EUS2': '293631485',
#      'ECO2_1': '-12161689.5',
#      'ECO2_2': '-5156556.348',
#      'GUS': '6889504',
#      'GUS1': '6462260',
#      'GUS2': '9524195',
#      'GCO2_1': '-1103723.5',
#      'GCO2_2': '-2472340.64',
#      'WUS': '12903778.6',
#      'WUS1': '12912643.2',
#      'WUS2': '13047876.3',
#      'WCO2_1': '-76481.15',
#      'WCO2_2': '-25391.7418',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-08-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '05',
#      'MM_TYPE': '공공기관',
#      'CNT': '2174',
#      'EUS': '162360569',
#      'EUS1': '159264299',
#      'EUS2': '168985705',
#      'ECO2_1': '-1764433',
#      'ECO2_2': '-748119.592',
#      'GUS': '10355264',
#      'GUS1': '9670111',
#      'GUS2': '4644170',
#      'GCO2_1': '3198123.5',
#      'GCO2_2': '7163796.64',
#      'WUS': '1523493.6',
#      'WUS1': '1481502',
#      'WUS2': '1496279',
#      'WCO2_1': '34603.1',
#      'WCO2_2': '11488.2292',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-08-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '05',
#      'MM_TYPE': '학교',
#      'CNT': '4033',
#      'EUS': '111393795',
#      'EUS1': '112986355',
#      'EUS2': '123821035',
#      'ECO2_1': '-7009900',
#      'ECO2_2': '-2972197.6',
#      'GUS': '2876433',
#      'GUS1': '2860196',
#      'GUS2': '3829983',
#      'GCO2_1': '-468656.5',
#      'GCO2_2': '-1049790.56',
#      'WUS': '3545592.2',
#      'WUS1': '3563788.4',
#      'WUS2': '3657234.144',
#      'WCO2_1': '-64919.072',
#      'WCO2_2': '-21553.131904',
#      'HUS': '1',
#      'HUS1': '1',
#      'HUS2': '1',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-08-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '05',
#      'MM_TYPE': '기업',
#      'CNT': '5657',
#      'EUS': '456001340',
#      'EUS1': '467855824',
#      'EUS2': '484856807',
#      'ECO2_1': '-20354975.5',
#      'ECO2_2': '-8630509.612',
#      'GUS': '9916284',
#      'GUS1': '10162792',
#      'GUS2': '13033952',
#      'GCO2_1': '-1682088',
#      'GCO2_2': '-3767877.12',
#      'WUS': '4071589.8',
#      'WUS1': '4133599',
#      'WUS2': '4122758',
#      'WCO2_1': '-56588.7',
#      'WCO2_2': '-18787.4484',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-08-05 04:00:01.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '06',
#      'MM_TYPE': '학교',
#      'CNT': '4056',
#      'EUS': '123484926',
#      'EUS1': '122180348',
#      'EUS2': '127693658',
#      'ECO2_1': '-1452077',
#      'ECO2_2': '-615680.648',
#      'GUS': '3244802',
#      'GUS1': '3125305',
#      'GUS2': '3372354',
#      'GCO2_1': '-4027.5',
#      'GCO2_2': '-9021.6',
#      'WUS': '3276567.2',
#      'WUS1': '3352073.02',
#      'WUS2': '3448123',
#      'WCO2_1': '-123530.81',
#      'WCO2_2': '-41012.22892',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-09-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '06',
#      'MM_TYPE': '기업',
#      'CNT': '5730',
#      'EUS': '504111937',
#      'EUS1': '517758806',
#      'EUS2': '537789216',
#      'ECO2_1': '-23662074',
#      'ECO2_2': '-10032719.376',
#      'GUS': '10171233',
#      'GUS1': '10849809',
#      'GUS2': '11575802',
#      'GCO2_1': '-1041572.5',
#      'GCO2_2': '-2333122.4',
#      'WUS': '4411615.4',
#      'WUS1': '4380714.8',
#      'WUS2': '4466132.4',
#      'WCO2_1': '-11808.2',
#      'WCO2_2': '-3920.3224',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-09-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '06',
#      'MM_TYPE': '개인',
#      'CNT': '813731',
#      'EUS': '186073153',
#      'EUS1': '191414452',
#      'EUS2': '196523474',
#      'ECO2_1': '-7895810',
#      'ECO2_2': '-3347823.44',
#      'GUS': '12677645',
#      'GUS1': '12887123',
#      'GUS2': '15272558',
#      'GCO2_1': '-1402195.5',
#      'GCO2_2': '-3140917.92',
#      'WUS': '14241651.402',
#      'WUS1': '14231573.864',
#      'WUS2': '14196573.165',
#      'WCO2_1': '27577.8875',
#      'WCO2_2': '9155.85865',
#      'HUS': '294312.634',
#      'HUS1': '301215.894',
#      'HUS2': '295514.063',
#      'HCO2_1': '-4052.3445',
#      'HCO2_2': '-90158.752204',
#      'REG_DATE': '2015-09-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '06',
#      'MM_TYPE': '종교단체',
#      'CNT': '265',
#      'EUS': '3299833',
#      'EUS1': '3968118',
#      'EUS2': '3981973',
#      'ECO2_1': '-675212.5',
#      'ECO2_2': '-286290.1',
#      'GUS': '109087',
#      'GUS1': '105760',
#      'GUS2': '112598',
#      'GCO2_1': '-92',
#      'GCO2_2': '-206.08',
#      'WUS': '36012',
#      'WUS1': '31614',
#      'WUS2': '36397',
#      'WCO2_1': '2006.5',
#      'WCO2_2': '666.158',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-09-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '06',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1750',
#      'EUS': '284934190',
#      'EUS1': '291783835',
#      'EUS2': '302110357',
#      'ECO2_1': '-12012906',
#      'ECO2_2': '-5093472.144',
#      'GUS': '3252225',
#      'GUS1': '3658733',
#      'GUS2': '3839871',
#      'GCO2_1': '-497077',
#      'GCO2_2': '-1113452.48',
#      'WUS': '13350376.8',
#      'WUS1': '13398512.2',
#      'WUS2': '13550273.56',
#      'WCO2_1': '-124016.08',
#      'WCO2_2': '-41173.33856',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-09-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '06',
#      'MM_TYPE': '공공기관',
#      'CNT': '2159',
#      'EUS': '170090446',
#      'EUS1': '169238218',
#      'EUS2': '174060526',
#      'ECO2_1': '-1558926',
#      'ECO2_2': '-660984.624',
#      'GUS': '6027916',
#      'GUS1': '6226686',
#      'GUS2': '6765517',
#      'GCO2_1': '-468185.5',
#      'GCO2_2': '-1048735.52',
#      'WUS': '1321635.6',
#      'WUS1': '1307294.2',
#      'WUS2': '1298322.2',
#      'WCO2_1': '18827.4',
#      'WCO2_2': '6250.6968',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-09-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '06',
#      'MM_TYPE': '소상공인',
#      'CNT': '12458',
#      'EUS': '47241419',
#      'EUS1': '47309268',
#      'EUS2': '48974798',
#      'ECO2_1': '-900614',
#      'ECO2_2': '-381860.336',
#      'GUS': '2267614',
#      'GUS1': '2275881',
#      'GUS2': '2864529',
#      'GCO2_1': '-302591',
#      'GCO2_2': '-677803.84',
#      'WUS': '1714846',
#      'WUS1': '1758867.2',
#      'WUS2': '1749829.307',
#      'WCO2_1': '-39502.2535',
#      'WCO2_2': '-13114.748162',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-09-05 04:00:01.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '07',
#      'MM_TYPE': '기업',
#      'CNT': '5809',
#      'EUS': '556996768',
#      'EUS1': '583699601',
#      'EUS2': '595041013',
#      'ECO2_1': '-32373539',
#      'ECO2_2': '-13726380.536',
#      'GUS': '12877575',
#      'GUS1': '13881727',
#      'GUS2': '15766106',
#      'GCO2_1': '-1946341.5',
#      'GCO2_2': '-4359804.96',
#      'WUS': '4433516.8',
#      'WUS1': '4458789.8',
#      'WUS2': '4462604',
#      'WCO2_1': '-27180.1',
#      'WCO2_2': '-9023.7932',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-10-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '07',
#      'MM_TYPE': '공공기관',
#      'CNT': '2083',
#      'EUS': '177529278',
#      'EUS1': '180512544',
#      'EUS2': '179850749',
#      'ECO2_1': '-2652368.5',
#      'ECO2_2': '-1124604.244',
#      'GUS': '2144272',
#      'GUS1': '2189006',
#      'GUS2': '2443392',
#      'GCO2_1': '-171927',
#      'GCO2_2': '-385116.48',
#      'WUS': '1502717',
#      'WUS1': '1476349.4',
#      'WUS2': '1481583.4',
#      'WCO2_1': '23750.6',
#      'WCO2_2': '7885.1992',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-10-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '07',
#      'MM_TYPE': '종교단체',
#      'CNT': '274',
#      'EUS': '3938240',
#      'EUS1': '4747560',
#      'EUS2': '4652038',
#      'ECO2_1': '-761559',
#      'ECO2_2': '-322901.016',
#      'GUS': '160725',
#      'GUS1': '161587',
#      'GUS2': '174638',
#      'GCO2_1': '-7387.5',
#      'GCO2_2': '-16548',
#      'WUS': '28997',
#      'WUS1': '28106',
#      'WUS2': '32088',
#      'WCO2_1': '-1100',
#      'WCO2_2': '-365.2',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-10-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '07',
#      'MM_TYPE': '학교',
#      'CNT': '4008',
#      'EUS': '115722596',
#      'EUS1': '120937114',
#      'EUS2': '119119922',
#      'ECO2_1': '-4305922',
#      'ECO2_2': '-1825710.928',
#      'GUS': '3616440',
#      'GUS1': '3588581',
#      'GUS2': '3721789',
#      'GCO2_1': '-38745',
#      'GCO2_2': '-86788.8',
#      'WUS': '2849735.4',
#      'WUS1': '2810214',
#      'WUS2': '2907085',
#      'WCO2_1': '-8914.1',
#      'WCO2_2': '-2959.4812',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-10-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '07',
#      'MM_TYPE': '개인',
#      'CNT': '823337',
#      'EUS': '165114568',
#      'EUS1': '171057688',
#      'EUS2': '176733530',
#      'ECO2_1': '-8781041',
#      'ECO2_2': '-3723161.384',
#      'GUS': '8893640',
#      'GUS1': '8706784',
#      'GUS2': '9439834',
#      'GCO2_1': '-179669',
#      'GCO2_2': '-402458.56',
#      'WUS': '12083879.038',
#      'WUS1': '12158770.739',
#      'WUS2': '12451976.253',
#      'WCO2_1': '-221494.458',
#      'WCO2_2': '-73536.160056',
#      'HUS': '702863.645',
#      'HUS1': '227748.982',
#      'HUS2': '218148.985',
#      'HCO2_1': '479914.6615',
#      'HCO2_2': '-29858.537272',
#      'REG_DATE': '2015-10-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '07',
#      'MM_TYPE': '소상공인',
#      'CNT': '12445',
#      'EUS': '53687603',
#      'EUS1': '54529034',
#      'EUS2': '55652598',
#      'ECO2_1': '-1403213',
#      'ECO2_2': '-594962.312',
#      'GUS': '2321747',
#      'GUS1': '2434263',
#      'GUS2': '3308804',
#      'GCO2_1': '-549786.5',
#      'GCO2_2': '-1231521.76',
#      'WUS': '1453718.2',
#      'WUS1': '1449232.922',
#      'WUS2': '1501927.6',
#      'WCO2_1': '-21862.061',
#      'WCO2_2': '-7258.204252',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-10-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '07',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1749',
#      'EUS': '293392343',
#      'EUS1': '303163814',
#      'EUS2': '314610261',
#      'ECO2_1': '-15494694.5',
#      'ECO2_2': '-6569750.468',
#      'GUS': '2711576',
#      'GUS1': '2593135',
#      'GUS2': '2958804',
#      'GCO2_1': '-64393.5',
#      'GCO2_2': '-144241.44',
#      'WUS': '13022088.4',
#      'WUS1': '12752055.2',
#      'WUS2': '12947100',
#      'WCO2_1': '172510.8',
#      'WCO2_2': '57273.5856',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-10-05 04:00:00.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '08',
#      'MM_TYPE': '개인',
#      'CNT': '831008',
#      'EUS': '242000479',
#      'EUS1': '225295114',
#      'EUS2': '251665825',
#      'ECO2_1': '3520009.5',
#      'ECO2_2': '1492484.028',
#      'GUS': '7619018',
#      'GUS1': '7818701',
#      'GUS2': '8690426',
#      'GCO2_1': '-635545.5',
#      'GCO2_2': '-1423621.92',
#      'WUS': '15164553.742',
#      'WUS1': '15186771.742',
#      'WUS2': '15162726.462',
#      'WCO2_1': '-10195.36',
#      'WCO2_2': '-3384.85952',
#      'HUS': '460288.965',
#      'HUS1': '446810.165',
#      'HUS2': '439663.894',
#      'HCO2_1': '17051.9355',
#      'HCO2_2': '-57105.653404',
#      'REG_DATE': '2015-11-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '08',
#      'MM_TYPE': '학교',
#      'CNT': '4051',
#      'EUS': '114182704',
#      'EUS1': '111674241',
#      'EUS2': '117842114',
#      'ECO2_1': '-575473.5',
#      'ECO2_2': '-244000.764',
#      'GUS': '3666183',
#      'GUS1': '3481385',
#      'GUS2': '3735537',
#      'GCO2_1': '57722',
#      'GCO2_2': '129297.28',
#      'WUS': '2646299',
#      'WUS1': '2695799.734',
#      'WUS2': '2704021',
#      'WCO2_1': '-53611.367',
#      'WCO2_2': '-17798.973844',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-11-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '08',
#      'MM_TYPE': '기업',
#      'CNT': '6002',
#      'EUS': '580517158',
#      'EUS1': '574017315',
#      'EUS2': '618846947',
#      'ECO2_1': '-15914973',
#      'ECO2_2': '-6747948.552',
#      'GUS': '14998047',
#      'GUS1': '15466844',
#      'GUS2': '18316687',
#      'GCO2_1': '-1893718.5',
#      'GCO2_2': '-4241929.44',
#      'WUS': '4860291.2',
#      'WUS1': '5109772.2',
#      'WUS2': '5077946.4',
#      'WCO2_1': '-233568.1',
#      'WCO2_2': '-77544.6092',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-11-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '08',
#      'MM_TYPE': '소상공인',
#      'CNT': '12907',
#      'EUS': '58830816',
#      'EUS1': '56284602',
#      'EUS2': '60743235',
#      'ECO2_1': '316897.5',
#      'ECO2_2': '134364.54',
#      'GUS': '2859077',
#      'GUS1': '2944081',
#      'GUS2': '4079953',
#      'GCO2_1': '-652940',
#      'GCO2_2': '-1462585.6',
#      'WUS': '1850611.8',
#      'WUS1': '1933054.818',
#      'WUS2': '1883652.4',
#      'WCO2_1': '-57741.809',
#      'WCO2_2': '-19170.280588',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-11-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '08',
#      'MM_TYPE': '공공기관',
#      'CNT': '2090',
#      'EUS': '194449748',
#      'EUS1': '187330536',
#      'EUS2': '192639612',
#      'ECO2_1': '4464674',
#      'ECO2_2': '1893021.776',
#      'GUS': '3142344',
#      'GUS1': '2859982',
#      'GUS2': '3734616',
#      'GCO2_1': '-154955',
#      'GCO2_2': '-347099.2',
#      'WUS': '1400970.4',
#      'WUS1': '1407303.4',
#      'WUS2': '1373127',
#      'WCO2_1': '10755.2',
#      'WCO2_2': '3570.7264',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-11-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '08',
#      'MM_TYPE': '종교단체',
#      'CNT': '282',
#      'EUS': '4684817',
#      'EUS1': '4990910',
#      'EUS2': '5000234',
#      'ECO2_1': '-310755',
#      'ECO2_2': '-131760.12',
#      'GUS': '183615',
#      'GUS1': '193447',
#      'GUS2': '216801',
#      'GCO2_1': '-21509',
#      'GCO2_2': '-48180.16',
#      'WUS': '42434',
#      'WUS1': '42692',
#      'WUS2': '38237',
#      'WCO2_1': '1969.5',
#      'WCO2_2': '653.874',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-11-05 04:00:00.0'},
#     {'YEAR': '2015',
#      'MON': '08',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1780',
#      'EUS': '347070626',
#      'EUS1': '324330654',
#      'EUS2': '366437506',
#      'ECO2_1': '1686546',
#      'ECO2_2': '715095.504',
#      'GUS': '2346260',
#      'GUS1': '2401138',
#      'GUS2': '2839274',
#      'GCO2_1': '-273946',
#      'GCO2_2': '-613639.04',
#      'WUS': '13735197.6',
#      'WUS1': '13718025.4',
#      'WUS2': '13752308.2',
#      'WCO2_1': '30.8',
#      'WCO2_2': '10.2256',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-11-05 04:00:00.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '09',
#      'MM_TYPE': '학교',
#      'CNT': '4104',
#      'EUS': '117000086',
#      'EUS1': '106788250',
#      'EUS2': '115993928',
#      'ECO2_1': '5608997',
#      'ECO2_2': '2378214.728',
#      'GUS': '3130770',
#      'GUS1': '2725587',
#      'GUS2': '3074109',
#      'GCO2_1': '230922',
#      'GCO2_2': '517265.28',
#      'WUS': '2286005',
#      'WUS1': '2289431',
#      'WUS2': '2367305.8',
#      'WCO2_1': '-42363.4',
#      'WCO2_2': '-14064.6488',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-12-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '09',
#      'MM_TYPE': '소상공인',
#      'CNT': '13215',
#      'EUS': '49906893',
#      'EUS1': '48338643',
#      'EUS2': '50163341',
#      'ECO2_1': '655901',
#      'ECO2_2': '278102.024',
#      'GUS': '1525269',
#      'GUS1': '1535097',
#      'GUS2': '1577271',
#      'GCO2_1': '-30915',
#      'GCO2_2': '-69249.6',
#      'WUS': '1497339.8',
#      'WUS1': '1517610',
#      'WUS2': '1531680.694',
#      'WCO2_1': '-27305.547',
#      'WCO2_2': '-9065.441604',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-12-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '09',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1775',
#      'EUS': '291193615',
#      'EUS1': '292423522',
#      'EUS2': '315758859',
#      'ECO2_1': '-12897575.5',
#      'ECO2_2': '-5468572.012',
#      'GUS': '1828671',
#      'GUS1': '2001182',
#      'GUS2': '2104570',
#      'GCO2_1': '-224205',
#      'GCO2_2': '-502219.2',
#      'WUS': '12661391.2',
#      'WUS1': '12587446.9',
#      'WUS2': '13062671.3',
#      'WCO2_1': '-163667.9',
#      'WCO2_2': '-54337.7428',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-12-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '09',
#      'MM_TYPE': '기업',
#      'CNT': '6544',
#      'EUS': '510981941',
#      'EUS1': '515975591',
#      'EUS2': '525800916',
#      'ECO2_1': '-9906312.5',
#      'ECO2_2': '-4200276.5',
#      'GUS': '9108483',
#      'GUS1': '8915531',
#      'GUS2': '9629814',
#      'GCO2_1': '-164189.5',
#      'GCO2_2': '-367784.48',
#      'WUS': '4966088.4',
#      'WUS1': '4950087.988',
#      'WUS2': '4994719',
#      'WCO2_1': '-6315.094',
#      'WCO2_2': '-2096.611208',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-12-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '09',
#      'MM_TYPE': '종교단체',
#      'CNT': '287',
#      'EUS': '4003389',
#      'EUS1': '4143180',
#      'EUS2': '4338032',
#      'ECO2_1': '-237217',
#      'ECO2_2': '-100580.008',
#      'GUS': '154103',
#      'GUS1': '141807',
#      'GUS2': '164321',
#      'GCO2_1': '1039',
#      'GCO2_2': '2327.36',
#      'WUS': '33319',
#      'WUS1': '33102',
#      'WUS2': '32863',
#      'WCO2_1': '336.5',
#      'WCO2_2': '111.718',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-12-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '09',
#      'MM_TYPE': '공공기관',
#      'CNT': '2114',
#      'EUS': '176575791',
#      'EUS1': '169676238',
#      'EUS2': '170595428',
#      'ECO2_1': '6439958',
#      'ECO2_2': '2730542.192',
#      'GUS': '2045113',
#      'GUS1': '1802312',
#      'GUS2': '2031916',
#      'GCO2_1': '127999',
#      'GCO2_2': '286717.76',
#      'WUS': '1674927',
#      'WUS1': '1639724',
#      'WUS2': '1612798.4',
#      'WCO2_1': '48665.8',
#      'WCO2_2': '16157.0456',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2015-12-05 04:00:01.0'},
#     {'YEAR': '2015',
#      'MON': '09',
#      'MM_TYPE': '개인',
#      'CNT': '836705',
#      'EUS': '207540868',
#      'EUS1': '206904741',
#      'EUS2': '227598380',
#      'ECO2_1': '-9710692.5',
#      'ECO2_2': '-4117333.62',
#      'GUS': '6518422',
#      'GUS1': '7398242',
#      'GUS2': '7043149',
#      'GCO2_1': '-702273.5',
#      'GCO2_2': '-1573092.64',
#      'WUS': '14419078.727',
#      'WUS1': '14517019.028',
#      'WUS2': '14835539.096',
#      'WCO2_1': '-257200.335',
#      'WCO2_2': '-85390.51122',
#      'HUS': '305710.728',
#      'HUS1': '1417941.207',
#      'HUS2': '1657911.407',
#      'HCO2_1': '-1232215.579',
#      'HCO2_2': '-627675.88577',
#      'REG_DATE': '2015-12-05 04:00:01.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '10',
#      'MM_TYPE': '개인',
#      'CNT': '838855',
#      'EUS': '186473958',
#      'EUS1': '190857499',
#      'EUS2': '196312194',
#      'ECO2_1': '-7110888.5',
#      'ECO2_2': '-3015016.724',
#      'GUS': '8924018',
#      'GUS1': '9776852',
#      'GUS2': '9992178',
#      'GCO2_1': '-960497',
#      'GCO2_2': '-2151513.28',
#      'WUS': '14711828.766',
#      'WUS1': '14806253.041',
#      'WUS2': '15009957.053',
#      'WCO2_1': '-196276.281',
#      'WCO2_2': '-65163.725292',
#      'HUS': '3167520.127',
#      'HUS1': '3791530.042',
#      'HUS2': '3875736.209',
#      'HCO2_1': '-666112.9985',
#      'HCO2_2': '-13312269.687023',
#      'REG_DATE': '2016-01-08 12:42:17.0'},
#     {'YEAR': '2015',
#      'MON': '10',
#      'MM_TYPE': '학교',
#      'CNT': '4105',
#      'EUS': '90894649',
#      'EUS1': '92776204',
#      'EUS2': '91074061',
#      'ECO2_1': '-1030483.5',
#      'ECO2_2': '-436925.004',
#      'GUS': '2198915',
#      'GUS1': '2032999',
#      'GUS2': '1898911',
#      'GCO2_1': '232960',
#      'GCO2_2': '521830.4',
#      'WUS': '2197092.6',
#      'WUS1': '2121219.6',
#      'WUS2': '2250504.8',
#      'WCO2_1': '11230.4',
#      'WCO2_2': '3728.4928',
#      'HUS': '123',
#      'HUS1': '272',
#      'HUS2': '272',
#      'HCO2_1': '-149',
#      'HCO2_2': '-593.318',
#      'REG_DATE': '2016-01-08 12:42:17.0'},
#     {'YEAR': '2015',
#      'MON': '10',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1781',
#      'EUS': '263666396',
#      'EUS1': '269259556',
#      'EUS2': '276975017',
#      'ECO2_1': '-9450890.5',
#      'ECO2_2': '-4007177.572',
#      'GUS': '2421770',
#      'GUS1': '2633859',
#      'GUS2': '2720728',
#      'GCO2_1': '-255523.5',
#      'GCO2_2': '-572372.64',
#      'WUS': '12836746.6',
#      'WUS1': '12982278.5',
#      'WUS2': '12979068',
#      'WCO2_1': '-143926.65',
#      'WCO2_2': '-47783.6478',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-01-08 12:42:17.0'},
#     {'YEAR': '2015',
#      'MON': '10',
#      'MM_TYPE': '기업',
#      'CNT': '6557',
#      'EUS': '429299432',
#      'EUS1': '440472251',
#      'EUS2': '451506225',
#      'ECO2_1': '-16689806',
#      'ECO2_2': '-7076477.744',
#      'GUS': '6739926',
#      'GUS1': '6841720',
#      'GUS2': '7175361',
#      'GCO2_1': '-268614.5',
#      'GCO2_2': '-601696.48',
#      'WUS': '4837079',
#      'WUS1': '4750659.4',
#      'WUS2': '4835618.8',
#      'WCO2_1': '43939.9',
#      'WCO2_2': '14588.0468',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-01-08 12:42:17.0'},
#     {'YEAR': '2015',
#      'MON': '10',
#      'MM_TYPE': '종교단체',
#      'CNT': '289',
#      'EUS': '3049721',
#      'EUS1': '3299519',
#      'EUS2': '3391534',
#      'ECO2_1': '-295805.5',
#      'ECO2_2': '-125421.532',
#      'GUS': '121469',
#      'GUS1': '109249',
#      'GUS2': '121459',
#      'GCO2_1': '6115',
#      'GCO2_2': '13697.6',
#      'WUS': '37276',
#      'WUS1': '31585',
#      'WUS2': '42832',
#      'WCO2_1': '67.5',
#      'WCO2_2': '22.41',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-01-08 12:42:17.0'},
#     {'YEAR': '2015',
#      'MON': '10',
#      'MM_TYPE': '공공기관',
#      'CNT': '2114',
#      'EUS': '149199842',
#      'EUS1': '144539538',
#      'EUS2': '144448249',
#      'ECO2_1': '4705948.5',
#      'ECO2_2': '1995322.164',
#      'GUS': '1446718',
#      'GUS1': '1479646',
#      'GUS2': '1362178',
#      'GCO2_1': '25806',
#      'GCO2_2': '57805.44',
#      'WUS': '1309059.4',
#      'WUS1': '1274242.8',
#      'WUS2': '1259365.6',
#      'WCO2_1': '42255.2',
#      'WCO2_2': '14028.7264',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-01-08 12:42:17.0'},
#     {'YEAR': '2015',
#      'MON': '10',
#      'MM_TYPE': '소상공인',
#      'CNT': '13298',
#      'EUS': '42023439',
#      'EUS1': '42298074',
#      'EUS2': '42740242',
#      'ECO2_1': '-495719',
#      'ECO2_2': '-210184.856',
#      'GUS': '1491721',
#      'GUS1': '1543973',
#      'GUS2': '1521445',
#      'GCO2_1': '-40988',
#      'GCO2_2': '-91813.12',
#      'WUS': '1426748.2',
#      'WUS1': '1406525.468',
#      'WUS2': '1408975.8',
#      'WCO2_1': '18997.566',
#      'WCO2_2': '6307.191912',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-01-08 12:42:17.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2015',
#      'MON': '11',
#      'MM_TYPE': '공공기관',
#      'CNT': '2116',
#      'EUS': '147686501',
#      'EUS1': '146594161',
#      'EUS2': '151248155',
#      'ECO2_1': '-1234657',
#      'ECO2_2': '-523494.568',
#      'GUS': '2443388',
#      'GUS1': '2572512',
#      'GUS2': '2707188',
#      'GCO2_1': '-196462',
#      'GCO2_2': '-440074.88',
#      'WUS': '1424682',
#      'WUS1': '1392070.8',
#      'WUS2': '1357145.6',
#      'WCO2_1': '50073.8',
#      'WCO2_2': '16624.5016',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-02-11 16:49:58.0'},
#     {'YEAR': '2015',
#      'MON': '11',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '1777',
#      'EUS': '277331848',
#      'EUS1': '282749386',
#      'EUS2': '290178463',
#      'ECO2_1': '-9132076.5',
#      'ECO2_2': '-3872000.436',
#      'GUS': '4777212',
#      'GUS1': '5031112',
#      'GUS2': '5740564',
#      'GCO2_1': '-608626',
#      'GCO2_2': '-1363322.24',
#      'WUS': '11935363.5',
#      'WUS1': '12008225.4',
#      'WUS2': '12098728.8',
#      'WCO2_1': '-118113.6',
#      'WCO2_2': '-39213.7152',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-02-11 16:49:58.0'},
#     {'YEAR': '2015',
#      'MON': '11',
#      'MM_TYPE': '종교단체',
#      'CNT': '288',
#      'EUS': '2690264',
#      'EUS1': '3028485',
#      'EUS2': '3155146',
#      'ECO2_1': '-401551.5',
#      'ECO2_2': '-170257.836',
#      'GUS': '123356',
#      'GUS1': '119110',
#      'GUS2': '132649',
#      'GCO2_1': '-2523.5',
#      'GCO2_2': '-5652.64',
#      'WUS': '30862',
#      'WUS1': '32542',
#      'WUS2': '32570',
#      'WCO2_1': '-1694',
#      'WCO2_2': '-562.408',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-02-11 16:49:58.0'},
#     {'YEAR': '2015',
#      'MON': '11',
#      'MM_TYPE': '기업',
#      'CNT': '6628',
#      'EUS': '411307841',
#      'EUS1': '421176794',
#      'EUS2': '438285942',
#      'ECO2_1': '-18423527',
#      'ECO2_2': '-7811575.448',
#      'GUS': '10579106',
#      'GUS1': '10608868',
#      'GUS2': '11899582',
#      'GCO2_1': '-675119',
#      'GCO2_2': '-1512266.56',
#      'WUS': '4087593.6',
#      'WUS1': '4047989.6',
#      'WUS2': '4068778.2',
#      'WCO2_1': '29209.7',
#      'WCO2_2': '9697.6204',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2016-02-11 16:49:58.0'},
#     {'YEAR': '2015',
#      'MON': '11',
#      'MM_TYPE': '학교',
#      'CNT': '4142',
#      'EUS': '97207264',
#      'EUS1': '98187897',
#      'EUS2': '103104980',
#      'ECO2_1': '-3439174.5',
#      'ECO2_2': '-1458209.988',
#      'GUS': '3129231',
#      'GUS1': '3428826',
#      'GUS2': '3894578',
#      'GCO2_1': '-532471',
#      'GCO2_2': '-1192735.04',
#      'WUS': '2479306.4',
#      'WUS1': '2407442.8',
#      'WUS2': '2499934.6',
#      'WCO2_1': '25617.7',
#      'WCO2_2': '8505.0764',
#      'HUS': '825',
#      'HUS1': '935',
#      'HUS2': '871',
#      'HCO2_1': '-78',
#      'HCO2_2': '-310.596',
#      'REG_DATE': '2016-02-11 16:49:58.0'},
#     {'YEAR': '2015',
#      'MON': '11',
#      'MM_TYPE': '개인',
#      'CNT': '849823',
#      'EUS': '196892030',
#      'EUS1': '200214469',
#      'EUS2': '204193971',
#      'ECO2_1': '-5312190',
#      'ECO2_2': '-2252368.56',
# ...
#      'HUS': '1',
#      'HUS1': '1',
#      'HUS2': '1',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2024-12-01 04:02:35.0'},
#     {'YEAR': '2024',
#      'MON': '09',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '3714',
#      'EUS': '760853331',
#      'EUS1': '653319317',
#      'EUS2': '593942556',
#      'ECO2_1': '137222394.5',
#      'ECO2_2': '137222394.5',
#      'GUS': '1550594',
#      'GUS1': '1629293',
#      'GUS2': '1642326',
#      'GCO2_1': '-85215.5',
#      'GCO2_2': '-170431',
#      'WUS': '20776020.6',
#      'WUS1': '20847307.1',
#      'WUS2': '21192982',
#      'WCO2_1': '-244123.95',
#      'WCO2_2': '-732371.85',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2024-12-01 04:02:35.0'},
#     {'YEAR': '2024',
#      'MON': '09',
#      'MM_TYPE': '공공기관',
#      'CNT': '2440',
#      'EUS': '187875055',
#      'EUS1': '183901926',
#      'EUS2': '171218971',
#      'ECO2_1': '10314606.5',
#      'ECO2_2': '10314606.5',
#      'GUS': '1697108',
#      'GUS1': '1674166',
#      'GUS2': '1614988',
#      'GCO2_1': '52531',
#      'GCO2_2': '105062',
#      'WUS': '1524589',
#      'WUS1': '1501372.2',
#      'WUS2': '1329069.2',
#      'WCO2_1': '109368.3',
#      'WCO2_2': '328104.9',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2024-12-01 04:02:35.0'},
#     {'YEAR': '2024',
#      'MON': '09',
#      'MM_TYPE': '종교단체',
#      'CNT': '848',
#      'EUS': '9159167',
#      'EUS1': '8355332',
#      'EUS2': '7215125',
#      'ECO2_1': '1373938.5',
#      'ECO2_2': '1373938.5',
#      'GUS': '207125',
#      'GUS1': '202220',
#      'GUS2': '177310',
#      'GCO2_1': '17360',
#      'GCO2_2': '34720',
#      'WUS': '48690',
#      'WUS1': '48880',
#      'WUS2': '47929',
#      'WCO2_1': '285.5',
#      'WCO2_2': '856.5',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2024-12-01 04:02:35.0'},
#     {'YEAR': '2024',
#      'MON': '09',
#      'MM_TYPE': '소상공인',
#      'CNT': '52400',
#      'EUS': '133894850',
#      'EUS1': '124709217',
#      'EUS2': '114663812',
#      'ECO2_1': '14208335.5',
#      'ECO2_2': '14196543.34',
#      'GUS': '1454687',
#      'GUS1': '1467975',
#      'GUS2': '1519793',
#      'GCO2_1': '-36980',
#      'GCO2_2': '-73960',
#      'WUS': '1557596.8',
#      'WUS1': '1558181.6',
#      'WUS2': '1542256.4',
#      'WCO2_1': '7377.8',
#      'WCO2_2': '21921.294',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2024-12-01 04:02:35.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2024',
#      'MON': '10',
#      'MM_TYPE': '개인',
#      'CNT': '1249966',
#      'EUS': '282268119',
#      'EUS1': '264132620',
#      'EUS2': '263389786',
#      'ECO2_1': '18506916',
#      'ECO2_2': '14379201.216',
#      'GUS': '8233421',
#      'GUS1': '9935192',
#      'GUS2': '12171887',
#      'GCO2_1': '-2811331.5',
#      'GCO2_2': '-5622663',
#      'WUS': '15297669.9',
#      'WUS1': '15372349.4',
#      'WUS2': '15520212.2',
#      'WCO2_1': '-148610.9',
#      'WCO2_2': '-189025.694',
#      'HUS': '2695491.396',
#      'HUS1': '3326775.236',
#      'HUS2': '4339830.387',
#      'HCO2_1': '-1137811.4155',
#      'HCO2_2': '-1573249.33785276',
#      'REG_DATE': '2025-01-01 04:02:38.0'},
#     {'YEAR': '2024',
#      'MON': '10',
#      'MM_TYPE': '소상공인',
#      'CNT': '52360',
#      'EUS': '98550603',
#      'EUS1': '92468461',
#      'EUS2': '92900164',
#      'ECO2_1': '5866290.5',
#      'ECO2_2': '5861400.548',
#      'GUS': '1370244',
#      'GUS1': '1409880',
#      'GUS2': '1486413',
#      'GCO2_1': '-75717',
#      'GCO2_2': '-151434',
#      'WUS': '1689455.6',
#      'WUS1': '1680333.9',
#      'WUS2': '1601534',
#      'WCO2_1': '48521.65',
#      'WCO2_2': '145306.154',
#      'HUS': '76',
#      'HUS1': '473',
#      'HUS2': '573',
#      'HCO2_1': '-447',
#      'HCO2_2': '-760.641872',
#      'REG_DATE': '2025-01-01 04:02:38.0'},
#     {'YEAR': '2024',
#      'MON': '10',
#      'MM_TYPE': '학교',
#      'CNT': '6733',
#      'EUS': '115103626',
#      'EUS1': '106444485',
#      'EUS2': '107842818',
#      'ECO2_1': '7959974.5',
#      'ECO2_2': '7951382.02',
#      'GUS': '1669712',
#      'GUS1': '1614829',
#      'GUS2': '1490040',
#      'GCO2_1': '117461.5',
#      'GCO2_2': '234923',
#      'WUS': '1795325.4',
#      'WUS1': '1910438.6',
#      'WUS2': '1766434.2',
#      'WCO2_1': '-43111',
#      'WCO2_2': '-130116.058',
#      'HUS': '974.188',
#      'HUS1': '1953.183',
#      'HUS2': '3138.018',
#      'HCO2_1': '-1571.4125',
#      'HCO2_2': '-2650.624498',
#      'REG_DATE': '2025-01-01 04:02:38.0'},
#     {'YEAR': '2024',
#      'MON': '10',
#      'MM_TYPE': '기업',
#      'CNT': '19429',
#      'EUS': '610283824',
#      'EUS1': '588734512',
#      'EUS2': '595170523',
#      'ECO2_1': '18331306.5',
#      'ECO2_2': '18331306.5',
#      'GUS': '15754501',
#      'GUS1': '16535150',
#      'GUS2': '14261837',
#      'GCO2_1': '356011.5',
#      'GCO2_2': '712023',
#      'WUS': '5377667',
#      'WUS1': '5161785.4',
#      'WUS2': '4921412.2',
#      'WCO2_1': '336068.2',
#      'WCO2_2': '1008204.6',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-01-01 04:02:38.0'},
#     {'YEAR': '2024',
#      'MON': '10',
#      'MM_TYPE': '공공기관',
#      'CNT': '2437',
#      'EUS': '150992531',
#      'EUS1': '140433495',
#      'EUS2': '143689146',
#      'ECO2_1': '8931210.5',
#      'ECO2_2': '8931210.5',
#      'GUS': '1248185',
#      'GUS1': '1242537',
#      'GUS2': '1182038',
#      'GCO2_1': '35897.5',
#      'GCO2_2': '71795',
#      'WUS': '1107020.8',
#      'WUS1': '1050022.4',
#      'WUS2': '936852.6',
#      'WCO2_1': '113583.3',
#      'WCO2_2': '340749.9',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-01-01 04:02:38.0'},
#     {'YEAR': '2024',
#      'MON': '10',
#      'MM_TYPE': '종교단체',
#      'CNT': '846',
#      'EUS': '6432735',
#      'EUS1': '5992884',
#      'EUS2': '5753892',
#      'ECO2_1': '559347',
#      'ECO2_2': '559347',
#      'GUS': '162714',
#      'GUS1': '165997',
#      'GUS2': '134884',
#      'GCO2_1': '12273.5',
#      'GCO2_2': '24547',
#      'WUS': '61242',
#      'WUS1': '57479',
#      'WUS2': '53761',
#      'WCO2_1': '5622',
#      'WCO2_2': '16866',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-01-01 04:02:38.0'},
#     {'YEAR': '2024',
#      'MON': '10',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '3714',
#      'EUS': '552698258',
#      'EUS1': '516428706',
#      'EUS2': '510905591',
#      'ECO2_1': '39031109.5',
#      'ECO2_2': '39031109.5',
#      'GUS': '1537542',
#      'GUS1': '1578100',
#      'GUS2': '1791884',
#      'GCO2_1': '-147450',
#      'GCO2_2': '-294900',
#      'WUS': '20951446.8',
#      'WUS1': '20582497.6',
#      'WUS2': '20857970.1',
#      'WCO2_1': '231212.95',
#      'WCO2_2': '693638.85',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-01-01 04:02:38.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2024',
#      'MON': '11',
#      'MM_TYPE': '공공기관',
#      'CNT': '2456',
#      'EUS': '141281942',
#      'EUS1': '145555106',
#      'EUS2': '141150651',
#      'ECO2_1': '-2070936.5',
#      'ECO2_2': '-2070936.5',
#      'GUS': '1070872',
#      'GUS1': '1130138',
#      'GUS2': '1360783',
#      'GCO2_1': '-174588.5',
#      'GCO2_2': '-349177',
#      'WUS': '1298952.2',
#      'WUS1': '1249794.4',
#      'WUS2': '1117201.2',
#      'WCO2_1': '115454.4',
#      'WCO2_2': '346363.2',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-02-01 04:02:31.0'},
#     {'YEAR': '2024',
#      'MON': '11',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '3716',
#      'EUS': '513006108',
#      'EUS1': '520865343',
#      'EUS2': '517968502',
#      'ECO2_1': '-6410814.5',
#      'ECO2_2': '-6410814.5',
#      'GUS': '2805906',
#      'GUS1': '3097258',
#      'GUS2': '4254575',
#      'GCO2_1': '-870201.5',
#      'GCO2_2': '-1740403',
#      'WUS': '20058538.8',
#      'WUS1': '20111429.6',
#      'WUS2': '20288869.6',
#      'WCO2_1': '-141610.8',
#      'WCO2_2': '-424832.4',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-02-01 04:02:31.0'},
#     {'YEAR': '2024',
#      'MON': '11',
#      'MM_TYPE': '기업',
#      'CNT': '19435',
#      'EUS': '598631634',
#      'EUS1': '587770481',
#      'EUS2': '572937864',
#      'ECO2_1': '18277461.5',
#      'ECO2_2': '18277461.5',
#      'GUS': '12400064',
#      'GUS1': '14444671',
#      'GUS2': '14116451',
#      'GCO2_1': '-1879883',
#      'GCO2_2': '-3759766',
#      'WUS': '4594903.6',
#      'WUS1': '4375363.1',
#      'WUS2': '4321442',
#      'WCO2_1': '246501.05',
#      'WCO2_2': '739503.15',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-02-01 04:02:31.0'},
#     {'YEAR': '2024',
#      'MON': '11',
#      'MM_TYPE': '종교단체',
#      'CNT': '848',
#      'EUS': '5676334',
#      'EUS1': '6023258',
#      'EUS2': '5692935',
#      'ECO2_1': '-181762.5',
#      'ECO2_2': '-181762.5',
#      'GUS': '119920',
#      'GUS1': '114857',
#      'GUS2': '142698',
#      'GCO2_1': '-8850.5',
#      'GCO2_2': '-17701',
#      'WUS': '50375',
#      'WUS1': '47628',
#      'WUS2': '44398',
#      'WCO2_1': '4362',
#      'WCO2_2': '13086',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-02-01 04:02:31.0'},
#     {'YEAR': '2024',
#      'MON': '11',
#      'MM_TYPE': '개인',
#      'CNT': '1251707',
#      'EUS': '257927956',
#      'EUS1': '263362159',
#      'EUS2': '265181268',
#      'ECO2_1': '-6343757.5',
#      'ECO2_2': '-4509835.42',
#      'GUS': '17418221',
#      'GUS1': '21047532',
#      'GUS2': '24761264',
#      'GCO2_1': '-5467227.5',
#      'GCO2_2': '-10934455',
#      'WUS': '14678672.5',
#      'WUS1': '14789968.4',
#      'WUS2': '15060759.3',
#      'WCO2_1': '-246691.35',
#      'WCO2_2': '-261007.97',
#      'HUS': '8836296.454',
#      'HUS1': '12932546.397',
#      'HUS2': '10390187.837',
#      'HCO2_1': '-2825070.663',
#      'HCO2_2': '-3892157.038064492',
#      'REG_DATE': '2025-02-01 04:02:31.0'},
#     {'YEAR': '2024',
#      'MON': '11',
#      'MM_TYPE': '학교',
#      'CNT': '6737',
#      'EUS': '114681352',
#      'EUS1': '121672088',
#      'EUS2': '115718834',
#      'ECO2_1': '-4014109',
#      'ECO2_2': '-4015420.264',
#      'GUS': '1191882',
#      'GUS1': '1272649',
#      'GUS2': '1529356',
#      'GCO2_1': '-208971',
#      'GCO2_2': '-417942',
#      'WUS': '1895457.4',
#      'WUS1': '1924656.6',
#      'WUS2': '1867820.2',
#      'WCO2_1': '-781',
#      'WCO2_2': '-1733.362',
#      'HUS': '8225.641',
#      'HUS1': '15064.331',
#      'HUS2': '9617.42',
#      'HCO2_1': '-4115.2345',
#      'HCO2_2': '-12501.137296',
#      'REG_DATE': '2025-02-01 04:02:31.0'},
#     {'YEAR': '2024',
#      'MON': '11',
#      'MM_TYPE': '소상공인',
#      'CNT': '52701',
#      'EUS': '88200257',
#      'EUS1': '91249175',
#      'EUS2': '88513537',
#      'ECO2_1': '-1681099',
#      'ECO2_2': '-1682933.848',
#      'GUS': '1486211',
#      'GUS1': '1575755',
#      'GUS2': '1677396',
#      'GCO2_1': '-138497.5',
#      'GCO2_2': '-276995',
#      'WUS': '1462455.8',
#      'WUS1': '1432459.5',
#      'WUS2': '1410209.4',
#      'WCO2_1': '41121.35',
#      'WCO2_2': '123015.876',
#      'HUS': '987',
#      'HUS1': '1331',
#      'HUS2': '1220',
#      'HCO2_1': '-288.5',
#      'HCO2_2': '-1061.209864',
#      'REG_DATE': '2025-02-01 04:02:31.0'}]}},
#  {'energyUseDataSummaryInfo': {'list_total_count': 7,
#    'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#    'row': [{'YEAR': '2024',
#      'MON': '12',
#      'MM_TYPE': '공동주택관리소',
#      'CNT': '3716',
#      'EUS': '548480228',
#      'EUS1': '557799290',
#      'EUS2': '559693904',
#      'ECO2_1': '-10266369',
#      'ECO2_2': '-10266369',
#      'GUS': '8221238',
#      'GUS1': '9759209',
#      'GUS2': '9093999',
#      'GCO2_1': '-1114991.5',
#      'GCO2_2': '-2229983',
#      'WUS': '20262147.7',
#      'WUS1': '20228097.5',
#      'WUS2': '20488646.8',
#      'WCO2_1': '-96224.45',
#      'WCO2_2': '-288673.35',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-03-01 04:02:55.0'},
#     {'YEAR': '2024',
#      'MON': '12',
#      'MM_TYPE': '기업',
#      'CNT': '19451',
#      'EUS': '633735769',
#      'EUS1': '641412053',
#      'EUS2': '669494932',
#      'ECO2_1': '-21717723.5',
#      'ECO2_2': '-21717723.5',
#      'GUS': '30096486',
#      'GUS1': '45742965',
#      'GUS2': '34384677',
#      'GCO2_1': '-9960022.5',
#      'GCO2_2': '-19920045',
#      'WUS': '4448777.4',
#      'WUS1': '4406465.4',
#      'WUS2': '4396396.4',
#      'WCO2_1': '47346.5',
#      'WCO2_2': '142039.5',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-03-01 04:02:55.0'},
#     {'YEAR': '2024',
#      'MON': '12',
#      'MM_TYPE': '개인',
#      'CNT': '1250620',
#      'EUS': '134828126',
#      'EUS1': '138280636',
#      'EUS2': '138879530',
#      'ECO2_1': '-3751957',
#      'ECO2_2': '-3504709',
#      'GUS': '42103424',
#      'GUS1': '47763373',
#      'GUS2': '46794290',
#      'GCO2_1': '-5135298',
#      'GCO2_2': '-10270596',
#      'WUS': '7326853.6',
#      'WUS1': '7440605',
#      'WUS2': '7625718.9',
#      'WCO2_1': '-206308.35',
#      'WCO2_2': '-573725.128',
#      'HUS': '1513199.277',
#      'HUS1': '1598857.184',
#      'HUS2': '1781397.386',
#      'HCO2_1': '-176928.008',
#      'HCO2_2': '-376996.699240516',
#      'REG_DATE': '2025-03-01 04:02:55.0'},
#     {'YEAR': '2024',
#      'MON': '12',
#      'MM_TYPE': '공공기관',
#      'CNT': '2459',
#      'EUS': '152992881',
#      'EUS1': '161100765',
#      'EUS2': '162060905',
#      'ECO2_1': '-8587954',
#      'ECO2_2': '-8587954',
#      'GUS': '3814815',
#      'GUS1': '4485938',
#      'GUS2': '4347791',
#      'GCO2_1': '-601856',
#      'GCO2_2': '-1203712',
#      'WUS': '896842',
#      'WUS1': '854671.2',
#      'WUS2': '833317.4',
#      'WCO2_1': '52847.7',
#      'WCO2_2': '158543.1',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-03-01 04:02:55.0'},
#     {'YEAR': '2024',
#      'MON': '12',
#      'MM_TYPE': '학교',
#      'CNT': '6742',
#      'EUS': '164092999',
#      'EUS1': '170867152',
#      'EUS2': '169660376',
#      'ECO2_1': '-6170678',
#      'ECO2_2': '-6172770.32',
#      'GUS': '4362563',
#      'GUS1': '4794450',
#      'GUS2': '4840884',
#      'GCO2_1': '-452916.5',
#      'GCO2_2': '-905833',
#      'WUS': '1858841',
#      'WUS1': '1898794',
#      'WUS2': '1939698.4',
#      'WCO2_1': '-60405.2',
#      'WCO2_2': '-181607.796',
#      'HUS': '1062.62',
#      'HUS1': '902.03',
#      'HUS2': '1220.91',
#      'HCO2_1': '1.15',
#      'HCO2_2': '3.3315',
#      'REG_DATE': '2025-03-01 04:02:55.0'},
#     {'YEAR': '2024',
#      'MON': '12',
#      'MM_TYPE': '소상공인',
#      'CNT': '53031',
#      'EUS': '101773064',
#      'EUS1': '105830842',
#      'EUS2': '106996097',
#      'ECO2_1': '-4640405.5',
#      'ECO2_2': '-4640315.356',
#      'GUS': '2544825',
#      'GUS1': '2719970',
#      'GUS2': '2842004',
#      'GCO2_1': '-234683',
#      'GCO2_2': '-469366',
#      'WUS': '1560686.6',
#      'WUS1': '1540086.6',
#      'WUS2': '1542971',
#      'WCO2_1': '19157.8',
#      'WCO2_2': '57349.338',
#      'HUS': '360',
#      'HUS1': '395',
#      'HUS2': '470',
#      'HCO2_1': '-72.5',
#      'HCO2_2': '-288.695',
#      'REG_DATE': '2025-03-01 04:02:55.0'},
#     {'YEAR': '2024',
#      'MON': '12',
#      'MM_TYPE': '종교단체',
#      'CNT': '847',
#      'EUS': '7922631',
#      'EUS1': '8361049',
#      'EUS2': '8016890',
#      'ECO2_1': '-266338.5',
#      'ECO2_2': '-266338.5',
#      'GUS': '309429',
#      'GUS1': '378759',
#      'GUS2': '355715',
#      'GCO2_1': '-57056.5',
#      'GCO2_2': '-114113',
#      'WUS': '51695',
#      'WUS1': '48661',
#      'WUS2': '48241',
#      'WCO2_1': '3244',
#      'WCO2_2': '9732',
#      'HUS': '0',
#      'HUS1': '0',
#      'HUS2': '0',
#      'HCO2_1': '0',
#      'HCO2_2': '0',
#      'REG_DATE': '2025-03-01 04:02:55.0'}]}}]

# %%
import pandas as pd

data_list = []

for res in responses:
    rows = res["energyUseDataSummaryInfo"]["row"]
    data_list.extend(rows)


df = pd.DataFrame(data_list)

#기본 정보 확인

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   YEAR      840 non-null    object
#  1   MON       840 non-null    object
#  2   MM_TYPE   840 non-null    object
#  3   CNT       840 non-null    object
#  4   EUS       840 non-null    object
#  5   EUS1      840 non-null    object
#  6   EUS2      840 non-null    object
#  7   ECO2_1    840 non-null    object
#  8   ECO2_2    840 non-null    object
#  9   GUS       840 non-null    object
#  10  GUS1      840 non-null    object
#  11  GUS2      840 non-null    object
#  12  GCO2_1    840 non-null    object
#  13  GCO2_2    840 non-null    object
#  14  WUS       840 non-null    object
#  15  WUS1      840 non-null    object
#  16  WUS2      840 non-null    object
#  17  WCO2_1    840 non-null    object
#  18  WCO2_2    840 non-null    object
#  19  HUS       840 non-null    object
#  20  HUS1      840 non-null    object
#  21  HUS2      840 non-null    object
#  22  HCO2_1    840 non-null    object
#  23  HCO2_2    840 non-null    object
#  24  REG_DATE  840 non-null    object
# dtypes: object(25)
# memory usage: 164.2+ KB
#         YEAR  MON MM_TYPE   CNT      EUS     EUS1     EUS2     ECO2_1  \
# count    840  840     840   840      840      840      840        840
# unique    10   12       7   746      840      840      840        840
# top     2015   01      개인  2365  7922631  8361049  8016890  -266338.5
# freq      84   70     120     8        1        1        1          1
#
#            ECO2_2     GUS  ... WUS1 WUS2 WCO2_1 WCO2_2  HUS HUS1 HUS2 HCO2_1  \
# count         840     840  ...  840  840    840    840  840  840  840    840
# unique        840     840  ...  837  837    837    837  301  299  300    290
# top     -266338.5  309429  ...    0    0      0      0    0    0    0      0
# freq            1       1  ...    4    4      4      4  524  524  524    549
#
#        HCO2_2               REG_DATE
# count     840                    840
# unique    290                    119
# top         0  2018-03-29 15:52:23.0
# freq      549                     14
#
# [4 rows x 25 columns]

# %%
df["MM_TYPE"] = df["MM_TYPE"].astype(str)
df_personal = df[df["MM_TYPE"] == "개인"]

selected_col = ["YEAR", "MON", "MM_TYPE", "EUS", "GUS", "WUS", "HUS"]
df_personal = df_personal[selected_col]
df_personal
# Out:
#      YEAR MON MM_TYPE        EUS       GUS           WUS           HUS
# 0    2015  01      개인  193784708  59133720  12819757.886  22740838.937
# 7    2015  02      개인  189974230  56487358  12656888.218  18793320.213
# 19   2015  03      개인  175215719  49984873  12655474.249  13826348.508
# 27   2015  04      개인  183891769  37306841  12954773.246   5836002.885
# 28   2015  05      개인  177289769  22060892  13086734.214   1320895.801
# ..    ...  ..     ...        ...       ...           ...           ...
# 809  2024  08      개인  463971328   7072251    15873544.6    130082.263
# 813  2024  09      개인  409872908   5729131    15143321.6   3420507.136
# 819  2024  10      개인  282268119   8233421    15297669.9   2695491.396
# 830  2024  11      개인  257927956  17418221    14678672.5   8836296.454
# 835  2024  12      개인  134828126  42103424     7326853.6   1513199.277
#
# [120 rows x 7 columns]

# %%
def get_season(month):
    if month in [3, 4, 5]:
        return "spring"
    elif month in [6, 7, 8]:
        return "summer"
    elif month in [9, 10, 11]:
        return "autumn"
    else:
        return "winter"

df_personal["season"] = df_personal["MON"].astype(int).apply(get_season)
df_personal
# Out:
#      YEAR MON MM_TYPE        EUS       GUS           WUS           HUS  season
# 0    2015  01      개인  193784708  59133720  12819757.886  22740838.937  winter
# 7    2015  02      개인  189974230  56487358  12656888.218  18793320.213  winter
# 19   2015  03      개인  175215719  49984873  12655474.249  13826348.508  spring
# 27   2015  04      개인  183891769  37306841  12954773.246   5836002.885  spring
# 28   2015  05      개인  177289769  22060892  13086734.214   1320895.801  spring
# ..    ...  ..     ...        ...       ...           ...           ...     ...
# 809  2024  08      개인  463971328   7072251    15873544.6    130082.263  summer
# 813  2024  09      개인  409872908   5729131    15143321.6   3420507.136  autumn
# 819  2024  10      개인  282268119   8233421    15297669.9   2695491.396  autumn
# 830  2024  11      개인  257927956  17418221    14678672.5   8836296.454  autumn
# 835  2024  12      개인  134828126  42103424     7326853.6   1513199.277  winter
#
# [120 rows x 8 columns]

# %%
df_personal = df_personal.reset_index(drop=True)

df_personal_renamed = df_personal.rename(columns={
    'YEAR': '연도',
    'MON': '월',
    'EUS': '전기',
    'GUS': '가스',
    'WUS': '수도',
    'HUS': '지역난방',
    'season': '계절'
    })
df_personal_renamed
# Out:
#        연도   월 MM_TYPE         전기        가스            수도          지역난방      계절
# 0    2015  01      개인  193784708  59133720  12819757.886  22740838.937  winter
# 1    2015  02      개인  189974230  56487358  12656888.218  18793320.213  winter
# 2    2015  03      개인  175215719  49984873  12655474.249  13826348.508  spring
# 3    2015  04      개인  183891769  37306841  12954773.246   5836002.885  spring
# 4    2015  05      개인  177289769  22060892  13086734.214   1320895.801  spring
# ..    ...  ..     ...        ...       ...           ...           ...     ...
# 115  2024  08      개인  463971328   7072251    15873544.6    130082.263  summer
# 116  2024  09      개인  409872908   5729131    15143321.6   3420507.136  autumn
# 117  2024  10      개인  282268119   8233421    15297669.9   2695491.396  autumn
# 118  2024  11      개인  257927956  17418221    14678672.5   8836296.454  autumn
# 119  2024  12      개인  134828126  42103424     7326853.6   1513199.277  winter
#
# [120 rows x 8 columns]
